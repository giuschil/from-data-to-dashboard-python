# %%
import pandas as pd
import numpy as np
import os

# %%
dc = pd.read_table(
    '/Users/giuseppe/Documents/GitHub/from-data-to-dashboard-python/dataset/dc-wikia-data.csv',
    sep = ',',
    dtype={'page_id':'int',
           'name':'string'})

# %%
dc.dtypes
# Out:
# page_id               int64
# name                 string
# urlslug              object
# ID                   object
# ALIGN                object
# EYE                  object
# HAIR                 object
# SEX                  object
# GSM                  object
# ALIVE                object
# APPEARANCES         float64
# FIRST APPEARANCE     object
# YEAR                float64
# dtype: object

# %%
dc = dc.rename(columns = lambda x: x.lower())

# %%
dc.head()
# Out:
#    page_id                         name                              urlslug  \
# 0     1422         Batman (Bruce Wayne)         \/wiki\/Batman_(Bruce_Wayne)
# 1    23387        Superman (Clark Kent)        \/wiki\/Superman_(Clark_Kent)
# 2     1458   Green Lantern (Hal Jordan)   \/wiki\/Green_Lantern_(Hal_Jordan)
# 3     1659     James Gordon (New Earth)     \/wiki\/James_Gordon_(New_Earth)
# 4     1576  Richard Grayson (New Earth)  \/wiki\/Richard_Grayson_(New_Earth)
#
#                 id            align         eye        hair              sex  \
# 0  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
# 1  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
# 2  Secret Identity  Good Characters  Brown Eyes  Brown Hair  Male Characters
# 3  Public Identity  Good Characters  Brown Eyes  White Hair  Male Characters
# 4  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
#
# ...

# %% [markdown]
# ### Basic operation

# %%
dc_2 = dc[['name','appearances','sex']]

# %%
#row filter 

dc_2_female = dc_2[dc_2.sex == 'Female Characters']

# %%
dc_2_female
# Out:
#                                 name  appearances                sex
# 5        Wonder Woman (Diana Prince)       1231.0  Female Characters
# 8     Dinah Laurel Lance (New Earth)       1075.0  Female Characters
# 10                        GenderTest       1028.0  Female Characters
# 12        Barbara Gordon (New Earth)        951.0  Female Characters
# 14             Lois Lane (New Earth)        934.0  Female Characters
# ...                              ...          ...                ...
# 6878       Dorothea Tane (New Earth)          NaN  Female Characters
# 6881          Doris Zuel (New Earth)          NaN  Female Characters
# 6882           Doris Lee (New Earth)          NaN  Female Characters
# 6885          Catwoman (Selina Kyle)          NaN  Female Characters
# 6891         Nadine West (New Earth)          NaN  Female Characters
#
# [1967 rows x 3 columns]

# %%
dc_2_male = dc_2[dc_2.sex == 'Male Characters']

# %%
dc_2_male
# Out:
#                               name  appearances              sex
# 0             Batman (Bruce Wayne)       3093.0  Male Characters
# 1            Superman (Clark Kent)       2496.0  Male Characters
# 2       Green Lantern (Hal Jordan)       1565.0  Male Characters
# 3         James Gordon (New Earth)       1316.0  Male Characters
# 4      Richard Grayson (New Earth)       1237.0  Male Characters
# ...                            ...          ...              ...
# 6890    James Garfield (New Earth)          NaN  Male Characters
# 6892    Warren Harding (New Earth)          NaN  Male Characters
# 6893  William Harrison (New Earth)          NaN  Male Characters
# 6894  William McKinley (New Earth)          NaN  Male Characters
# 6895            Mookie (New Earth)          NaN  Male Characters
#
# [4783 rows x 3 columns]

# %%
dc\
[['name','appearances','sex']]\
[dc_2.sex == 'Female Characters']
# Out:
#                                 name  appearances                sex
# 5        Wonder Woman (Diana Prince)       1231.0  Female Characters
# 8     Dinah Laurel Lance (New Earth)       1075.0  Female Characters
# 10                        GenderTest       1028.0  Female Characters
# 12        Barbara Gordon (New Earth)        951.0  Female Characters
# 14             Lois Lane (New Earth)        934.0  Female Characters
# ...                              ...          ...                ...
# 6878       Dorothea Tane (New Earth)          NaN  Female Characters
# 6881          Doris Zuel (New Earth)          NaN  Female Characters
# 6882           Doris Lee (New Earth)          NaN  Female Characters
# 6885          Catwoman (Selina Kyle)          NaN  Female Characters
# 6891         Nadine West (New Earth)          NaN  Female Characters
#
# [1967 rows x 3 columns]

# %%
#column selection 
dc.loc[:,'name':'year']
# Out:
#                               name                               urlslug  \
# 0             Batman (Bruce Wayne)          \/wiki\/Batman_(Bruce_Wayne)
# 1            Superman (Clark Kent)         \/wiki\/Superman_(Clark_Kent)
# 2       Green Lantern (Hal Jordan)    \/wiki\/Green_Lantern_(Hal_Jordan)
# 3         James Gordon (New Earth)      \/wiki\/James_Gordon_(New_Earth)
# 4      Richard Grayson (New Earth)   \/wiki\/Richard_Grayson_(New_Earth)
# ...                            ...                                   ...
# 6891       Nadine West (New Earth)       \/wiki\/Nadine_West_(New_Earth)
# 6892    Warren Harding (New Earth)    \/wiki\/Warren_Harding_(New_Earth)
# 6893  William Harrison (New Earth)  \/wiki\/William_Harrison_(New_Earth)
# 6894  William McKinley (New Earth)  \/wiki\/William_McKinley_(New_Earth)
# 6895            Mookie (New Earth)            \/wiki\/Mookie_(New_Earth)
#
#                    id            align         eye        hair  \
# ...

# %%
dc.drop(columns=['page_id','urlslug'])
# Out:
#                               name               id            align  \
# 0             Batman (Bruce Wayne)  Secret Identity  Good Characters
# 1            Superman (Clark Kent)  Secret Identity  Good Characters
# 2       Green Lantern (Hal Jordan)  Secret Identity  Good Characters
# 3         James Gordon (New Earth)  Public Identity  Good Characters
# 4      Richard Grayson (New Earth)  Secret Identity  Good Characters
# ...                            ...              ...              ...
# 6891       Nadine West (New Earth)  Public Identity  Good Characters
# 6892    Warren Harding (New Earth)  Public Identity  Good Characters
# 6893  William Harrison (New Earth)  Public Identity  Good Characters
# 6894  William McKinley (New Earth)  Public Identity  Good Characters
# 6895            Mookie (New Earth)  Public Identity   Bad Characters
#
#              eye        hair                sex  gsm              alive  \
# ...

# %%
# trovami la colonna che finisce con la parola 
dc.filter(regex ='appearance$', axis =1)
# Out:
#      first appearance
# 0           1939, May
# 1       1986, October
# 2       1959, October
# 3      1987, February
# 4         1940, April
# ...               ...
# 6891              NaN
# 6892              NaN
# 6893              NaN
# 6894              NaN
# 6895              NaN
#
# [6896 rows x 1 columns]

# %%
#prendimi le colonne numeriche
dc.select_dtypes(np.number)
# Out:
#       page_id  appearances    year
# 0        1422       3093.0  1939.0
# 1       23387       2496.0  1986.0
# 2        1458       1565.0  1959.0
# 3        1659       1316.0  1987.0
# 4        1576       1237.0  1940.0
# ...       ...          ...     ...
# 6891    66302          NaN     NaN
# 6892   283475          NaN     NaN
# 6893   283478          NaN     NaN
# 6894   283471          NaN     NaN
# 6895   150660          NaN     NaN
#
# [6896 rows x 3 columns]

# %%
#prendimi tutte tranne le colonne stringe
dc.select_dtypes(exclude='string')
# Out:
#       page_id                               urlslug               id  \
# 0        1422          \/wiki\/Batman_(Bruce_Wayne)  Secret Identity
# 1       23387         \/wiki\/Superman_(Clark_Kent)  Secret Identity
# 2        1458    \/wiki\/Green_Lantern_(Hal_Jordan)  Secret Identity
# 3        1659      \/wiki\/James_Gordon_(New_Earth)  Public Identity
# 4        1576   \/wiki\/Richard_Grayson_(New_Earth)  Secret Identity
# ...       ...                                   ...              ...
# 6891    66302       \/wiki\/Nadine_West_(New_Earth)  Public Identity
# 6892   283475    \/wiki\/Warren_Harding_(New_Earth)  Public Identity
# 6893   283478  \/wiki\/William_Harrison_(New_Earth)  Public Identity
# 6894   283471  \/wiki\/William_McKinley_(New_Earth)  Public Identity
# 6895   150660            \/wiki\/Mookie_(New_Earth)  Public Identity
#
#                 align         eye        hair                sex  gsm  \
# ...

# %%
#mostrami i valori unici
dc.sex.unique()
# Out:
# array(['Male Characters', 'Female Characters', nan,
#        'Genderless Characters', 'Transgender Characters'], dtype=object)

# %%
#mostrami il numero di valori unici
dc.sex.nunique(dropna=False)
# Out:
# 5

# %%
#filtri per righe 
dc[dc.sex.eq('Female Characters') & dc.hair.eq('Blond Hair')]
# Out:
#       page_id                             name  \
# 8       71760   Dinah Laurel Lance (New Earth)
# 10     403631                       GenderTest
# 21       1580           Kara Zor-L (Earth-Two)
# 38       1607  Cassandra Sandsmark (New Earth)
# 67       1696    Courtney Whitmore (New Earth)
# ...       ...                              ...
# 6832   186945       High Priestess (Earth-One)
# 6841    34616         Rebecca Tane (New Earth)
# 6842     3033           Doreen Day (New Earth)
# 6858    10536  Angel Beatrix O'Day (New Earth)
# 6878    34617        Dorothea Tane (New Earth)
#
#                                         urlslug               id  \
# 8        \/wiki\/Dinah_Laurel_Lance_(New_Earth)  Public Identity
# 10                           \/wiki\/GenderTest  Secret Identity
# 21               \/wiki\/Kara_Zor-L_(Earth-Two)  Secret Identity
# 38      \/wiki\/Cassandra_Sandsmark_(New_Earth)  Public Identity
# 67        \/wiki\/Courtney_Whitmore_(New_Earth)  Secret Identity
# ...

# %%
#condizioni righe in or 
dc[dc.sex.eq('Female Characters') | dc.hair.eq('Blond Hair')]
# Out:
#       page_id                            name  \
# 5        1448     Wonder Woman (Diana Prince)
# 6        1486          Aquaman (Arthur Curry)
# 8       71760  Dinah Laurel Lance (New Earth)
# 9        1380             Flash (Barry Allen)
# 10     403631                      GenderTest
# ...       ...                             ...
# 6881     1624          Doris Zuel (New Earth)
# 6882    22701           Doris Lee (New Earth)
# 6885     1460          Catwoman (Selina Kyle)
# 6891    66302         Nadine West (New Earth)
# 6895   150660              Mookie (New Earth)
#
#                                      urlslug               id  \
# 5        \/wiki\/Wonder_Woman_(Diana_Prince)  Public Identity
# 6             \/wiki\/Aquaman_(Arthur_Curry)  Public Identity
# 8     \/wiki\/Dinah_Laurel_Lance_(New_Earth)  Public Identity
# 9                \/wiki\/Flash_(Barry_Allen)  Secret Identity
# 10                        \/wiki\/GenderTest  Secret Identity
# ...

# %%
#condizioni righe in and
dc[dc.sex.eq('Female Characters') & dc.hair.eq('Blond Hair')]
